# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data1 = pd.read_csv("evolutionaryAlgoOutput.csv")
data2 = pd.read_csv("evolutionaryAlgoOutput2.csv")
# data3 = pd.read_csv("evolutionaryAlgoOutput2_test.csv")
max1 = max(data1.iloc[:, 1])
max2 = max(data2.iloc[:, 1])
# max3 = max(data3.iloc[:, 1])
print(len(data1))
xPos = len(data1) / 1.5
yPos = min(data1.iloc[:, 1]) + 50
print(yPos)
plt.figure(figsize = (12, 8))
plt.title("Genetic Algorithm Revenues")
plt.plot(data1.iloc[:, 0], data1.iloc[:, 1], label = "Single Mutation + Crossover (Greedy)")
plt.plot(data2.iloc[:, 0], data2.iloc[:, 1], label = "Multiple crossover points + Mutation, (Elitism)")
# plt.plot(data3.iloc[:, 0], data3.iloc[:, 1])
plt.text(xPos, yPos + 50, str("BestRevenue of Solution 1: "+str(max1)))
plt.text(xPos, yPos+25, str("BestRevenue of Solution 2: "+str(max2)))
# plt.text(xPos, yPos, str("BestRevenue of Solution 3: "+str(max3)))
plt.xlabel("Generations")
plt.ylabel("Revenue")
plt.legend()
plt.savefig("Output plots.png")
plt.plot()
# Out:
# 100
# 2517.78
# []
